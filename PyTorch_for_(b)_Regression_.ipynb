# %%
import torch
import torch.nn as nn
import torchvision
import numpy as np
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# %%
input_size = 784#here we are going to use PyTorch MNIST dataset. Will talk of custom dataset afterwards. Size of image is 28x28, hence if we make them a 1-D vector then it is 784
output_size = 10#total possible output 0-9
num_epochs = 20
batch_size = 100#total number of images is 60000
learning_rate = 0.001
#here we are using PyTorch dataset hence torchvision.datasets.MNIST, then the image is normal array to convert them to tensor we use transforms.ToTensor()
#later we will see that we can include many other transforms here also.
train_dataset = torchvision.datasets.MNIST(root='Data', train = True, transform = transforms.ToTensor(), download = True) 
test_dataset = torchvision.datasets.MNIST(root='Data', train = False, transform= transforms.ToTensor())
train_loader = torch.utils.data.DataLoader(dataset = train_dataset, batch_size = batch_size, shuffle = True)
test_loader = torch.utils.data.DataLoader(dataset = test_dataset, batch_size = batch_size, shuffle = False)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to Data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting Data/MNIST/raw/train-images-idx3-ubyte.gz to Data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to Data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting Data/MNIST/raw/train-labels-idx1-ubyte.gz to Data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to Data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting Data/MNIST/raw/t10k-images-idx3-ubyte.gz to Data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to Data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting Data/MNIST/raw/t10k-labels-idx1-ubyte.gz to Data/MNIST/raw

# %%
input_size = 784
hidden_size = 100
num_classes = 10
learning_rate = 0.001
num_epochs = 5
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(NeuralNet, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, num_classes)
    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        return out
    
model = NeuralNet(input_size, hidden_size, num_classes).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(),lr = learning_rate)

total_step = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        images = images.reshape(-1,28*28).to(device)
        labels = labels.to(device)
        outputs = model(images)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        if (i+1) % 100 == 0:
            print ('Epoch [{}/{}], Iteration [{}/{}], Loss: {:.4f}' 
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))
with torch.no_grad():
    correct = 0 
    total = 0
    for images, labels in (test_loader):
        images= images.reshape(-1, 28*28).to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total+=predicted.size(0)
        correct += (predicted==labels).sum()
        
    print('Accuracy of the network on the 10000 test images: {} %'.format(100 * correct / total))
# Out:
# Epoch [1/5], Iteration [100/600], Loss: 0.4746
# Epoch [1/5], Iteration [200/600], Loss: 0.2943
# Epoch [1/5], Iteration [300/600], Loss: 0.3378
# Epoch [1/5], Iteration [400/600], Loss: 0.3503
# Epoch [1/5], Iteration [500/600], Loss: 0.2397
# Epoch [1/5], Iteration [600/600], Loss: 0.2730
# Epoch [2/5], Iteration [100/600], Loss: 0.1357
# Epoch [2/5], Iteration [200/600], Loss: 0.1186
# Epoch [2/5], Iteration [300/600], Loss: 0.2123
# Epoch [2/5], Iteration [400/600], Loss: 0.1564
# Epoch [2/5], Iteration [500/600], Loss: 0.1595
# Epoch [2/5], Iteration [600/600], Loss: 0.1365
# Epoch [3/5], Iteration [100/600], Loss: 0.1231
# Epoch [3/5], Iteration [200/600], Loss: 0.1205
# Epoch [3/5], Iteration [300/600], Loss: 0.1951
# Epoch [3/5], Iteration [400/600], Loss: 0.1357
# Epoch [3/5], Iteration [500/600], Loss: 0.2023
# Epoch [3/5], Iteration [600/600], Loss: 0.1068
# Epoch [4/5], Iteration [100/600], Loss: 0.0834
# Epoch [4/5], Iteration [200/600], Loss: 0.1408
# Epoch [4/5], Iteration [300/600], Loss: 0.1004
# Epoch [4/5], Iteration [400/600], Loss: 0.1420
# Epoch [4/5], Iteration [500/600], Loss: 0.1659
# Epoch [4/5], Iteration [600/600], Loss: 0.0730
# Epoch [5/5], Iteration [100/600], Loss: 0.2401
# Epoch [5/5], Iteration [200/600], Loss: 0.0780
# Epoch [5/5], Iteration [300/600], Loss: 0.0400
# Epoch [5/5], Iteration [400/600], Loss: 0.0284
# Epoch [5/5], Iteration [500/600], Loss: 0.0879
# Epoch [5/5], Iteration [600/600], Loss: 0.1025
# Accuracy of the network on the 10000 test images: 97.02999877929688 %

# %%
######################################

# %% [markdown]
# INCREASING LEARNING RATE TO 0.1

# %%
input_size = 784
hidden_size = 100
num_classes = 10
learning_rate = 0.1
num_epochs = 10
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(NeuralNet, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, num_classes)
    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        return out
    
model = NeuralNet(input_size, hidden_size, num_classes).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(),lr = learning_rate)

total_step = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        images = images.reshape(-1,28*28).to(device)
        labels = labels.to(device)
        outputs = model(images)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        if (i+1) % 100 == 0:
            print ('Epoch [{}/{}], Iteration [{}/{}], Loss: {:.4f}' 
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))
with torch.no_grad():
    correct = 0 
    total = 0
    for images, labels in (test_loader):
        images= images.reshape(-1, 28*28).to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total+=predicted.size(0)
        correct += (predicted==labels).sum()
        
    print('Accuracy of the network on the 10000 test images: {} %'.format(100 * correct / total))
# Out:
# Epoch [1/5], Iteration [100/600], Loss: 1.0992
# Epoch [1/5], Iteration [200/600], Loss: 0.5802
# Epoch [1/5], Iteration [300/600], Loss: 0.6152
# Epoch [1/5], Iteration [400/600], Loss: 0.6145
# Epoch [1/5], Iteration [500/600], Loss: 0.5953
# Epoch [1/5], Iteration [600/600], Loss: 0.3993
# Epoch [2/5], Iteration [100/600], Loss: 0.7192
# Epoch [2/5], Iteration [200/600], Loss: 0.6048
# Epoch [2/5], Iteration [300/600], Loss: 0.7203
# Epoch [2/5], Iteration [400/600], Loss: 0.9924
# Epoch [2/5], Iteration [500/600], Loss: 0.4247
# Epoch [2/5], Iteration [600/600], Loss: 0.5964
# Epoch [3/5], Iteration [100/600], Loss: 0.6372
# Epoch [3/5], Iteration [200/600], Loss: 1.0358
# Epoch [3/5], Iteration [300/600], Loss: 0.5466
# Epoch [3/5], Iteration [400/600], Loss: 0.8621
# Epoch [3/5], Iteration [500/600], Loss: 0.8863
# Epoch [3/5], Iteration [600/600], Loss: 0.7456
# Epoch [4/5], Iteration [100/600], Loss: 0.7275
# Epoch [4/5], Iteration [200/600], Loss: 0.5644
# Epoch [4/5], Iteration [300/600], Loss: 0.7544
# Epoch [4/5], Iteration [400/600], Loss: 0.4971
# Epoch [4/5], Iteration [500/600], Loss: 0.6852
# Epoch [4/5], Iteration [600/600], Loss: 0.3726
# Epoch [5/5], Iteration [100/600], Loss: 0.5587
# Epoch [5/5], Iteration [200/600], Loss: 0.5772
# Epoch [5/5], Iteration [300/600], Loss: 0.6585
# Epoch [5/5], Iteration [400/600], Loss: 0.8166
# Epoch [5/5], Iteration [500/600], Loss: 0.6058
# Epoch [5/5], Iteration [600/600], Loss: 0.6746
# Accuracy of the network on the 10000 test images: 80.4800033569336 %

# %% [markdown]
# OBSERVED ACCURACY GOT DECREASED TO 80.48%

# %%
##################################

# %%
INCREASING HIDDEN SIZE(NUMBER OF NEURONS) TO 1000

# %%
input_size = 784
hidden_size = 1000
num_classes = 10
learning_rate = 0.001
num_epochs = 5
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(NeuralNet, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, num_classes)
    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        return out
    
model = NeuralNet(input_size, hidden_size, num_classes).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(),lr = learning_rate)

total_step = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        images = images.reshape(-1,28*28).to(device)
        labels = labels.to(device)
        outputs = model(images)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        if (i+1) % 100 == 0:
            print ('Epoch [{}/{}], Iteration [{}/{}], Loss: {:.4f}' 
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))
with torch.no_grad():
    correct = 0 
    total = 0
    for images, labels in (test_loader):
        images= images.reshape(-1, 28*28).to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total+=predicted.size(0)
        correct += (predicted==labels).sum()
        
    print('Accuracy of the network on the 10000 test images: {} %'.format(100 * correct / total))
# Out:
# Epoch [1/5], Iteration [100/600], Loss: 0.2987
# Epoch [1/5], Iteration [200/600], Loss: 0.1826
# Epoch [1/5], Iteration [300/600], Loss: 0.1981
# Epoch [1/5], Iteration [400/600], Loss: 0.2719
# Epoch [1/5], Iteration [500/600], Loss: 0.1902
# Epoch [1/5], Iteration [600/600], Loss: 0.2509
# Epoch [2/5], Iteration [100/600], Loss: 0.1223
# Epoch [2/5], Iteration [200/600], Loss: 0.0376
# Epoch [2/5], Iteration [300/600], Loss: 0.0862
# Epoch [2/5], Iteration [400/600], Loss: 0.0665
# Epoch [2/5], Iteration [500/600], Loss: 0.0788
# Epoch [2/5], Iteration [600/600], Loss: 0.0701
# Epoch [3/5], Iteration [100/600], Loss: 0.0452
# Epoch [3/5], Iteration [200/600], Loss: 0.1042
# Epoch [3/5], Iteration [300/600], Loss: 0.0429
# Epoch [3/5], Iteration [400/600], Loss: 0.0207
# Epoch [3/5], Iteration [500/600], Loss: 0.0297
# Epoch [3/5], Iteration [600/600], Loss: 0.0804
# Epoch [4/5], Iteration [100/600], Loss: 0.0353
# Epoch [4/5], Iteration [200/600], Loss: 0.0092
# Epoch [4/5], Iteration [300/600], Loss: 0.0742
# Epoch [4/5], Iteration [400/600], Loss: 0.0180
# Epoch [4/5], Iteration [500/600], Loss: 0.0622
# Epoch [4/5], Iteration [600/600], Loss: 0.0826
# Epoch [5/5], Iteration [100/600], Loss: 0.0127
# Epoch [5/5], Iteration [200/600], Loss: 0.0109
# Epoch [5/5], Iteration [300/600], Loss: 0.0230
# Epoch [5/5], Iteration [400/600], Loss: 0.0158
# Epoch [5/5], Iteration [500/600], Loss: 0.0416
# Epoch [5/5], Iteration [600/600], Loss: 0.0097
# Accuracy of the network on the 10000 test images: 98.0999984741211 %

# %% [markdown]
# OBSERVED ACCURACY GOT INCREASED BY INCREASING NUMBER OF HIDDEN LAYER NEURONS.

# %%
######################

# %% [markdown]
# Increased number of epochs

# %%
input_size = 784
hidden_size = 100
num_classes = 10
learning_rate = 0.001
num_epochs = 10
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(NeuralNet, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, num_classes)
    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        return out
    
model = NeuralNet(input_size, hidden_size, num_classes).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(),lr = learning_rate)

total_step = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        images = images.reshape(-1,28*28).to(device)
        labels = labels.to(device)
        outputs = model(images)
        loss = criterion(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        if (i+1) % 100 == 0:
            print ('Epoch [{}/{}], Iteration [{}/{}], Loss: {:.4f}' 
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))
with torch.no_grad():
    correct = 0 
    total = 0
    for images, labels in (test_loader):
        images= images.reshape(-1, 28*28).to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total+=predicted.size(0)
        correct += (predicted==labels).sum()
        
    print('Accuracy of the network on the 10000 test images: {} %'.format(100 * correct / total))
# Out:
# Epoch [1/10], Iteration [100/600], Loss: 0.4946
# Epoch [1/10], Iteration [200/600], Loss: 0.3246
# Epoch [1/10], Iteration [300/600], Loss: 0.3993
# Epoch [1/10], Iteration [400/600], Loss: 0.1998
# Epoch [1/10], Iteration [500/600], Loss: 0.2124
# Epoch [1/10], Iteration [600/600], Loss: 0.2856
# Epoch [2/10], Iteration [100/600], Loss: 0.3346
# Epoch [2/10], Iteration [200/600], Loss: 0.1676
# Epoch [2/10], Iteration [300/600], Loss: 0.1086
# Epoch [2/10], Iteration [400/600], Loss: 0.1452
# Epoch [2/10], Iteration [500/600], Loss: 0.1810
# Epoch [2/10], Iteration [600/600], Loss: 0.1855
# Epoch [3/10], Iteration [100/600], Loss: 0.1105
# Epoch [3/10], Iteration [200/600], Loss: 0.0979
# Epoch [3/10], Iteration [300/600], Loss: 0.1191
# Epoch [3/10], Iteration [400/600], Loss: 0.3034
# Epoch [3/10], Iteration [500/600], Loss: 0.2155
# Epoch [3/10], Iteration [600/600], Loss: 0.2149
# Epoch [4/10], Iteration [100/600], Loss: 0.1188
# Epoch [4/10], Iteration [200/600], Loss: 0.0786
# Epoch [4/10], Iteration [300/600], Loss: 0.2371
# Epoch [4/10], Iteration [400/600], Loss: 0.1526
# Epoch [4/10], Iteration [500/600], Loss: 0.1238
# Epoch [4/10], Iteration [600/600], Loss: 0.1301
# Epoch [5/10], Iteration [100/600], Loss: 0.1039
# Epoch [5/10], Iteration [200/600], Loss: 0.0744
# Epoch [5/10], Iteration [300/600], Loss: 0.0850
# Epoch [5/10], Iteration [400/600], Loss: 0.1696
# Epoch [5/10], Iteration [500/600], Loss: 0.0845
# Epoch [5/10], Iteration [600/600], Loss: 0.0452
# Epoch [6/10], Iteration [100/600], Loss: 0.0842
# Epoch [6/10], Iteration [200/600], Loss: 0.1100
# Epoch [6/10], Iteration [300/600], Loss: 0.0542
# Epoch [6/10], Iteration [400/600], Loss: 0.1076
# Epoch [6/10], Iteration [500/600], Loss: 0.0391
# Epoch [6/10], Iteration [600/600], Loss: 0.0460
# Epoch [7/10], Iteration [100/600], Loss: 0.0410
# Epoch [7/10], Iteration [200/600], Loss: 0.0734
# Epoch [7/10], Iteration [300/600], Loss: 0.0473
# Epoch [7/10], Iteration [400/600], Loss: 0.0986
# Epoch [7/10], Iteration [500/600], Loss: 0.0564
# Epoch [7/10], Iteration [600/600], Loss: 0.0763
# Epoch [8/10], Iteration [100/600], Loss: 0.0898
# Epoch [8/10], Iteration [200/600], Loss: 0.0413
# Epoch [8/10], Iteration [300/600], Loss: 0.0180
# Epoch [8/10], Iteration [400/600], Loss: 0.0900
# Epoch [8/10], Iteration [500/600], Loss: 0.0688
# Epoch [8/10], Iteration [600/600], Loss: 0.0263
# Epoch [9/10], Iteration [100/600], Loss: 0.0525
# Epoch [9/10], Iteration [200/600], Loss: 0.0750
# Epoch [9/10], Iteration [300/600], Loss: 0.1323
# Epoch [9/10], Iteration [400/600], Loss: 0.0152
# Epoch [9/10], Iteration [500/600], Loss: 0.0205
# Epoch [9/10], Iteration [600/600], Loss: 0.0398
# Epoch [10/10], Iteration [100/600], Loss: 0.0328
# Epoch [10/10], Iteration [200/600], Loss: 0.0165
# Epoch [10/10], Iteration [300/600], Loss: 0.0292
# Epoch [10/10], Iteration [400/600], Loss: 0.0225
# Epoch [10/10], Iteration [500/600], Loss: 0.0086
# Epoch [10/10], Iteration [600/600], Loss: 0.0633
# Accuracy of the network on the 10000 test images: 97.62999725341797 %

# %%
#Observed a slight increase in accuracy by increasing number of epochs
